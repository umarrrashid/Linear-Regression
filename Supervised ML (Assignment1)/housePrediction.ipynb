# %%
import pandas as pd

df = pd.read_csv("data.csv")

# %%
data = pd.read_csv("data.csv")

# %%
# Data Preprocessing - Data cleaning

# Drop Id as it doesn't contribute in price
# data.drop(['Id'],
#              axis=1,
#              inplace=True)

# Replacing SalePrice empty values with their mean values
data['SalePrice'] = data['SalePrice'].fillna(
  data['SalePrice'].mean()) 

# Drop records with null values
df = data.dropna()

data.isnull().sum()
data.head()
data.fillna(0, inplace=True)

# %%
# Data Preprocessing - Encoding (Covered in Supervised ML Part2)
cols = ['MSZoning', 'LotConfig', 'BldgType', 'Exterior1st']
df = pd.get_dummies(data, columns=cols, drop_first=True)

data.head()
# Out:
#    MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  YearBuilt  \
# 0          60       RL     8450    Inside     1Fam            5       2003
# 1          20       RL     9600       FR2     1Fam            8       1976
# 2          60       RL    11250    Inside     1Fam            5       2001
# 3          70       RL     9550    Corner     1Fam            5       1915
# 4          60       RL    14260       FR2     1Fam            5       2000
#
#    YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  SalePrice
# 0          2003     VinylSd         0.0        856.0   208500.0
# 1          1976     MetalSd         0.0       1262.0   181500.0
# 2          2002     VinylSd         0.0        920.0   223500.0
# 3          1970     Wd Sdng         0.0        756.0   140000.0
# 4          2000     VinylSd         0.0       1145.0   250000.0

# %%
# Train-Test Split
from sklearn.model_selection import train_test_split

X = df.drop(['SalePrice'], axis=1)
Y = df['SalePrice']

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, random_state=0)

# %%
X_test.head()
# Out:
#       MSSubClass  LotArea  OverallCond  YearBuilt  YearRemodAdd  BsmtFinSF2  \
# 1815          30     8520            8       1923          1950         0.0
# 2871          30     8088            3       1922          1955         0.0
# 1232          90     9842            5       1962          1962         0.0
# 1977          60    16451            5       2003          2003         0.0
# 22            20     9742            5       2002          2002         0.0
#
#       TotalBsmtSF  MSZoning_C (all)  MSZoning_FV  MSZoning_RH  ...  \
# 1815        624.0             False        False        False  ...
# 2871        498.0             False        False        False  ...
# 1232          0.0             False        False        False  ...
# 1977       1765.0             False        False        False  ...
# 22         1777.0             False        False        False  ...
#
#       Exterior1st_CemntBd  Exterior1st_HdBoard  Exterior1st_ImStucc  \
# 1815                False                False                False
# 2871                False                False                False
# 1232                False                 True                False
# 1977                False                False                False
# 22                  False                False                False
#
#       Exterior1st_MetalSd  Exterior1st_Plywood  Exterior1st_Stone  \
# 1815                False                False              False
# 2871                 True                False              False
# 1232                False                False              False
# 1977                False                False              False
# 22                  False                False              False
#
#       Exterior1st_Stucco  Exterior1st_VinylSd  Exterior1st_Wd Sdng  \
# 1815                True                False                False
# 2871               False                False                False
# 1232               False                False                False
# 1977               False                 True                False
# 22                 False                 True                False
#
#       Exterior1st_WdShing
# 1815                False
# 2871                False
# 1232                False
# 1977                False
# 22                  False
#
# [5 rows x 35 columns]

# %%
# Train Linear Regression Model
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
print("R2 Score : ",r2_score(y_test,y_pred))
# Out:
# R2 Score :  0.3539449937289141
